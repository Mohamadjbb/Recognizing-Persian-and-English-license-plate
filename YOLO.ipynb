# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 872.8/872.8 kB 7.3 MB/s eta 0:00:00
# ...

# %%
import ultralytics
from ultralytics import YOLO
import cv2
from PIL import Image
from IPython.display import Video
import matplotlib.pyplot as plt
from IPython.display import display
import torch
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.2.95 🚀 Python-3.10.12 torch-2.4.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 32.9/112.6 GB disk)

# %%
model_en = YOLO("yolov8n.pt")
# Out:
# ...
# 100%|██████████| 6.25M/6.25M [00:00<00:00, 362MB/s]

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="JgCvr6upV0t85y8P8eyJ")
project = rf.workspace("marcin-brzeaski").project("anpr-wpigd")
version = project.version(1)
dataset = version.download("yolov8")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.3/80.3 kB 2.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 6.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 4.8 MB/s eta 0:00:00
# ...
#   Attempting uninstall: idna
#     Found existing installation: idna 3.8
#     Uninstalling idna-3.8:
#       Successfully uninstalled idna-3.8
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# Dependency ultralytics==8.0.196 is required but found version=8.2.95, to fix: `pip install ultralytics==8.0.196`
# ...
# Extracting Dataset Version Zip to ANPR-1 in yolov8:: 100%|██████████| 1298/1298 [00:00<00:00, 7176.74it/s]

# %%
results = model2.train(data='/content/ANPR-1/data.yaml', epochs=9, imgsz=1000)
# Out:
# Ultralytics YOLOv8.2.92 🚀 Python-3.10.12 torch-2.4.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
results = model_en.train(data='/content/ANPR-1/data.yaml', epochs=9, imgsz=1000)
# Out:
# Ultralytics YOLOv8.2.95 🚀 Python-3.10.12 torch-2.4.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
model2.export()
# Out:
# Ultralytics YOLOv8.2.92 🚀 Python-3.10.12 torch-2.4.0+cu121 CPU (Intel Xeon 2.20GHz)
# Model summary (fused): 168 layers, 3,006,428 parameters, 0 gradients, 8.1 GFLOPs
#
# PyTorch: starting from 'runs/detect/train5/weights/best.pt' with input shape (1, 3, 1024, 1024) BCHW and output shape(s) (1, 8, 21504) (6.0 MB)
#
# TorchScript: starting export with torch 2.4.0+cu121...
# TorchScript: export success ✅ 3.3s, saved as 'runs/detect/train5/weights/best.torchscript' (12.1 MB)
#
# Export complete (5.5s)
# Results saved to /content/runs/detect/train5/weights
# Predict:         yolo predict task=detect model=runs/detect/train5/weights/best.torchscript imgsz=1024
# Validate:        yolo val task=detect model=runs/detect/train5/weights/best.torchscript imgsz=1024 data=/content/ANPR-1/data.yaml
# Visualize:       https://netron.app
# 'runs/detect/train5/weights/best.torchscript'

# %%
model_en.export()
# Out:
# Ultralytics YOLOv8.2.95 🚀 Python-3.10.12 torch-2.4.0+cu121 CPU (Intel Xeon 2.00GHz)
# Model summary (fused): 168 layers, 3,006,428 parameters, 0 gradients, 8.1 GFLOPs
#
# PyTorch: starting from 'runs/detect/train3/weights/best.pt' with input shape (1, 3, 1024, 1024) BCHW and output shape(s) (1, 8, 21504) (6.0 MB)
#
# TorchScript: starting export with torch 2.4.0+cu121...
# TorchScript: export success ✅ 4.5s, saved as 'runs/detect/train3/weights/best.torchscript' (12.1 MB)
#
# Export complete (6.7s)
# Results saved to /content/runs/detect/train3/weights
# Predict:         yolo predict task=detect model=runs/detect/train3/weights/best.torchscript imgsz=1024
# Validate:        yolo val task=detect model=runs/detect/train3/weights/best.torchscript imgsz=1024 data=/content/ANPR-1/data.yaml
# Visualize:       https://netron.app
# 'runs/detect/train3/weights/best.torchscript'

# %%
model_2 = YOLO('/content/runs/detect/train5/weights/best.pt')

# %%
model_en = YOLO('/content/runs/detect/train3/weights/best.pt')

# %%
test_result = model_2.predict(source='/content/ANPR-1/test/images/*.jpg')
# Out:
# image 1/64 /content/ANPR-1/test/images/105_jpg.rf.71c0523e39eba7560e7980e7aea12705.jpg: 1024x1024 1 license-plate, 13.3ms
# image 2/64 /content/ANPR-1/test/images/124_jpg.rf.b7ff375e784288fb53fcb44322b1ed22.jpg: 1024x1024 1 license-plate, 13.3ms
# image 3/64 /content/ANPR-1/test/images/130_jpg.rf.c1dc3328fd676119dbca3f1a54098a82.jpg: 1024x1024 1 license-plate, 13.3ms
# image 4/64 /content/ANPR-1/test/images/133_jpg.rf.72923d6d0e3f8825bc5a75cb69a02760.jpg: 1024x1024 1 license-plate, 13.3ms
# image 5/64 /content/ANPR-1/test/images/170_jpg.rf.322ec2b9623cd55a716f51e29c05cc20.jpg: 1024x1024 1 license-plate, 13.3ms
# image 6/64 /content/ANPR-1/test/images/17_jpg.rf.b79db98b648129b4068d03cefd4e4606.jpg: 1024x1024 1 license-plate, 13.3ms
# image 7/64 /content/ANPR-1/test/images/181_jpg.rf.26e01c406cb1e07ccc0aab4d4fb2f19d.jpg: 1024x1024 1 license-plate, 13.3ms
# image 8/64 /content/ANPR-1/test/images/184_jpg.rf.aabc60b3d4dda7995e8d36a02451868e.jpg: 1024x1024 1 license-plate, 13.3ms
# ...

# %%
test_result = model_en.predict(source='/content/ANPR-1/test/images/*.jpg')

# %%
img1 = test_result[0].plot()
img1 = cv2.cvtColor(img1, cv2.COLOR_BGR2RGB)
img1 = Image.fromarray(img1)
img1 = img1.resize((400,400))
img2 = test_result[1].plot()
img2 = cv2.cvtColor(img2, cv2.COLOR_BGR2RGB)
img2 = Image.fromarray(img2)
img2 = img2.resize((400,400))
img3 = test_result[2].plot()
img3 = cv2.cvtColor(img3, cv2.COLOR_BGR2RGB)
img3 = Image.fromarray(img3)
img3 = img3.resize((400,400))
img4 = test_result[3].plot()
img4 = cv2.cvtColor(img4, cv2.COLOR_BGR2RGB)
img4 = Image.fromarray(img4)
img4 = img4.resize((400,400))

# %%
total_width = img1.width + img2.width + img3.width + img4.width
max_height = max(img1.height, img2.height, img3.height,img4.height)
final_image = Image.new('RGB', (total_width, max_height))

# Paste resized images onto the final image
final_image.paste(img1, (0, 0))
final_image.paste(img2, (img1.width, 0))
final_image.paste(img3, (img1.width + img2.width, 0))
final_image.paste(img4, (img1.width + img2.width + img3.width, 0))

# Display the final image
display(final_image)
# Out:
# <PIL.Image.Image image mode=RGB size=1600x400>

# %%
model_2.save('plate.pt')
